# %%
from modules import pygooglenews 
from modules.pygooglenews import GoogleNews
from datetime import datetime
from newspaper import Article
from collections import Counter
import re

gn = GoogleNews()

# %%
# Create frequency count for russia ukraine conflict at peak

start_date = datetime(2022, 6, 1).date()
end_date = datetime(2022, 12, 30).date()
start_date_str = start_date.strftime('%Y-%m-%d')
end_date_str = end_date.strftime('%Y-%m-%d')
entire_text = ""
articles = []
peak_news = gn.search('allintext:(invasion OR conflict OR war OR crisis + ukraine + russia)', from_ = start_date_str, to_ = end_date_str)
for entry in peak_news["entries"]:
    print(entry["title"])
    articles.append(entry["link"])

# for article in articles:
#     try:
#         scraper = Article(article)
#         scraper.download()
#         scraper.parse()
#         text = scraper.text
#         entire_text += text

#     except Exception as e:
#         print(f"Error parsing article: {e}")

#print(entire_text)
# cleaned_text = re.sub(r'[^\w\s]', ' ', entire_text.lower())
#analyse word frequency

exclude_words = non_noun_adjective_verb_words = [
    # key words
    "russia", "ukraine", "russian", "ukrainian", "kyiv", "moscow"
    # Articles
    "a", "an", "the",
    
    # Prepositions
    "about", "above", "across", "after", "against", "along", "amid", "among", "around", "as", 
    "at", "before", "behind", "below", "beneath", "beside", "between", "beyond", "but", "by", 
    "despite", "down", "during", "except", "for", "from", "in", "inside", "into", "like", "near", 
    "of", "off", "on", "onto", "out", "outside", "over", "past", "per", "through", "throughout", 
    "to", "toward", "under", "underneath", "until", "up", "upon", "with", "within", "without",
    
    # Conjunctions
    "and", "but", "or", "nor", "for", "so", "yet", 
    
    # Pronouns
    "I", "you", "he", "she", "it", "we", "they", "me", "him", "her", "us", "them", "my", "mine", 
    "your", "yours", "his", "her", "hers", "its", "our", "ours", "their", "theirs", "what", "who", 
    "which", "whom", "whose", "this", "that", "these", "those", "such", "many", "much", "few", 
    "little", "more", "most", "some", "any", "each", "every", "all", "another", "other", "same", 
    "one", "two", "three", "four", "five", "first", "second", "last", 
    
    # Interjections
    "wow", "ouch", "oops", "oh", "yeah", "yikes", "ugh", "uh-huh", "uh-oh", "hmm", "huh",
    
    # Others
    "etc", "et al", "e.g.", "i.e.", "etc.", "has", "have", "would", "should", "if", "is", "am", 
    "are", "be", "been", "being", "was", "were", "can", "could", "may", "might", "must", "shall", 
    "should", "will", "would", "shall", "should", "could", "might", "must", "would", "wont", "wont", 
    "cant", "couldnt", "didnt", "doesnt", "dont", "hadnt", "hasnt", "havent", "havnt", "isnt", "shouldnt", 
    "wasnt", "werent", "wont", "not", "now", "make", "things", "given", "also", "said", "states", "world", 
    "western", "there", "had"
]


# word_counter = Counter(word for word in cleaned_text.split() if word not in exclude_words and len(word) > 1)

# print(word_counter)
# Out:
# NATO Review - The consequences of Russia's invasion of Ukraine for international security – NATO and beyond - NATO HQ
# Timeline: Six months of Russia’s war in Ukraine - Al Jazeera English
# Russia's Ill-Fated Invasion of Ukraine: Lessons in Modern Warfare - CSIS | Center for Strategic and International Studies
# Ukraine war: Russia not to blame for conflict - Putin - BBC.com
# China's Strategic Calculations in the Russia-Ukraine War - Wilson Center
# Russia's War in Ukraine Could Raise Poverty in Caucasus, Central Asia - International Monetary Fund
# Russia says United States is directly involved in Ukraine war - Reuters
# The United States Speaks Clearly on Russia's Ukraine War - United States Institute of Peace
# The Russia-Ukraine war and its ramifications for Russia | Brookings - Brookings Institution
# What caused the war in Ukraine? | The Strategist - The Strategist
# Russia Suffers 'Catastrophic Strategic Disaster' in Ukraine > U.S - Department of Defense
# ...

# %%
word_freq_peak = {
    'war': 1021,
    'putin': 488,
    'military': 417,
    'invasion': 271,
    'forces': 246,
    'support': 233,
    'security': 227,
    'european': 224,
    'nuclear': 221,
    'country': 221,
    'europe': 206,
    'united': 199,
    'president': 191,
    'conflict': 170,
    'ukrainians': 167,
    'government': 167,
    'west': 166,
    'international': 165,
    'weapons': 158,
    'kremlin': 153,
    'russians': 132,
    'china': 125,
    'energy': 122,
    'troops': 115,
    'economic': 114,
    'biden': 113,
    'intelligence': 110,
    'sanctions': 109,
    'territory': 109,
    'political': 108,
    'peace': 105,
    'very': 105,
    'global': 105,
    'power': 103,
    'february': 102,
    'still': 101,
    'far': 101,
    'media': 101,
    'fighting': 100,
    'washington': 100,
    'foreign': 99,
    'however': 98,
    'need': 97,
    'union': 96,
    'policy': 96,
    'part': 95,
    'social': 95,
    'back': 94,
    'percent': 91,
    'take': 90,
    'allies': 89,
    'officials': 89,
    'region': 89,
    'soviet': 88,
    'likely': 85,
    'way': 85,
    'strategic': 84,
    '24': 83,
    'change': 83,
    'march': 82,
    'poland': 82,
    'threat': 81,
    'defence': 81,
    'where': 81,
    'crimea': 79,
    'defense': 78,
    'day': 77,
    'leaders': 77,
    'control': 76,
    'according': 75,
    'miles': 75,
    'attack': 75,
    'then': 75,
    'think': 75,
    'week': 75,
    'scale': 74,
    'public': 74,
    'see': 74,
    'national': 73,
    'armed': 73,
    'right': 73,
    'information': 72,
    'help': 71,
    'clear': 71,
    'zelensky': 71,
    'drones': 71,
    'used': 71,
    'did': 71,
    'disinformation': 71,
    'economy': 70,
    'future': 70,
    'east': 70,
    'possible': 69,
    'efforts': 69,
    'assistance': 69,
    'become': 69,
    'attacks': 69,
    'kherson': 68,
    'council': 67,
    'city': 66,
    'least': 66,
    'aid': 66,
    'recent': 66,
    'crisis': 66,
    'order': 65,
    'force': 65,
    'minister': 65,
    'south': 65,
    'going': 65,
    'important': 65,
    'continue': 65,
    'member': 64,
    'vladimir': 64,
    '10': 64,
    'aggression': 63,
    'says': 63,
    'administration': 63,
    'key': 63,
    'relations': 63,
    'general': 62,
    'further': 62,
    'already': 62,
    'range': 62,
    'fight': 62,
    'point': 62,
    'june': 61,
    'air': 61,
    'full': 61,
    'term': 60,
    'based': 60,
    'say': 60,
    'battlefield': 60,
    'germany': 60,
    'told': 60,
    'victory': 59,
    'example': 59,
    'early': 59,
    'senior': 59,
    'equipment': 58,
    'billion': 58,
    'army': 58,
    'wars': 58,
    'decision': 57,
    'high': 57,
    'systems': 56,
    'soldiers': 56,
    'great': 56,
    'domestic': 56,
    '2014': 56,
    'taiwan': 56,
    'too': 55,
    'direct': 55,
    'sea': 55,
    'position': 55,
    'often': 55,
    'side': 55,
    'today': 54,
    'iran': 54,
    'provide': 53,
    'believe': 53,
    'american': 52,
    'significant': 52,
    'role': 52,
    'major': 51,
    'strategy': 51,
    'partners': 51,
    'deal': 51,
    'gas': 50,
    'alliance': 50,
    'strike': 50,
    'infrastructure': 49,
    'missile': 49,
    'response': 49,
    'supply': 49,
    'negotiations': 48,
    'civilians': 47,
    'human': 47,
    'drone': 47,
    'france': 47,
    'escalation': 47,
    'diplomatic': 47,
    'leader': 47,
    'million': 46,
    'areas': 46,
    'leadership': 45,
    'rather': 45,
    'north': 45,
    'food': 45,
    'humanitarian': 45,
    'lead': 45,
    'called': 45,
    'top': 44,
    'ground': 44,
    'special': 44,
    'missiles': 44,
    'law': 44,
    'border': 44,
    'german': 44,
    'itself': 43,
    'threats': 43,
    'nations': 43,
    'summit': 43,
    'territorial': 42,
    'critical': 42,
    'land': 42,
    'battle': 42,
    'began': 42,
    'history': 41,
    'thousands': 41,
    'regime': 41,
    'risk': 41,
    'better': 41,
    'access': 41,
    'campaign': 40,
    'occupied': 40,
    'nearly': 40,
    'difficult': 40,
    'killed': 39,
    'targets': 39,
    'good': 39,
    'best': 39,
    'community': 39,
    'defend': 39,
    'diplomacy': 39,
    'level': 38,
    'using': 38,
    'black': 38, 
    'financial': 38,
    'geopolitical': 38,
    'question': 38,
    'director': 38,
    'territories': 37,
    'open': 37,
    'capabilities': 37,
    'agreement': 37,
    'together': 37,
    'plans': 37,
    'meeting': 37,
    'issues': 37,
    'taking': 37,
    'operations': 37,
    'secretary': 37,
    'regions': 37,
    'place': 37,
    'governments': 37,
    'warfare': 37,
    'platforms': 37,
    'destroyed': 36,
    'consequences': 36,
    'strong': 36,
    'members': 36,
    'away': 36,
    'artillery': 36,
    'month': 36,
    'winter': 36,
    'november': 36,
    'evidence': 36,
    'view': 36,
    'reason': 36,
    'americans': 36,
    'something': 35,
    'heavy': 35,
    'coming': 35,
    'real': 35,
    'atlantic': 35,
    'plan': 35,
    'found': 35,
    'close': 35,
    'don': 35,
    'short': 35,
    'turn': 35,
    'actions': 35,
    'talks': 35,
    'borders': 35,
    'know': 35,
    'fellow': 35,
    'damage': 34,
    'costs': 34,
    'losses': 34,
    'necessary': 34,
    'thus': 34,
    'oil': 34,
    'civilian': 34,
    'remain': 34,
    're': 34,
    'enough': 34,
    'longer': 34,
        'keep': 34,
    'september': 34,
    'pressure': 34,
    'chinese': 34,
    'believed': 34,
    'provided': 34,
    'british': 34,
    'main': 33,
    'operation': 33,
    'training': 33,
    'volodymyr': 33,
    '300': 33,
    'proxy': 33,
    'following': 33,
    'different': 33,
    'makes sense': 33,
    'data': 33,
    'former': 33,
    'true': 33,
    'certainly': 33,
    'cost': 33,
    'house': 33,
    'never': 33,
    'democracy': 33,
    'health': 33,
    'goal': 32,
    'cold': 32,
    'increasingly': 32,
    'avoid': 32,
    'speed': 32,
    'independence': 32,
    'free': 32,
    'ongoing': 31,
    'mariupol': 31,
    'look': 31,
    'strikes': 31,
    'next': 31,
    'supplies': 31,
    'due': 31,
    'present': 31,
    'grain': 31,
    'gains': 31,
    'exports': 31,
    'august': 31,
    'lines': 31,
    'citizens': 31,
    'themselves': 31,
    'left': 31,
    'earlier': 31,
    'indeed': 31,
    'feb': 31,
    'let': 31,
    'bergmann': 31,
    'ready': 30,
    'largest': 30,
    'launched': 30,
    'ammunition': 30,
    'lost': 30,
    'offensive': 30,
    'home': 30,
    'negotiate': 30,
    'push': 30,
    'hard': 30,
    'commitment': 30,
    'cooperation': 30,
    'possibility': 30,
    'middle': 30,
    'powerful': 30,
    'defeat': 30,
    'wanted': 30,
    'rau': 30,
    'georgian': 30,
    '30': 29,
    'hundreds': 29,
    'result': 29,
    'combat': 29,
    'towards': 29,
    'capital': 29,
    'status': 29,
    'sovereignty': 29,
    'invaded': 29,
    'office': 29,
    'anti': 29,
    'nation': 29,
    'committed': 29,
    'neither': 29,
    'non': 29,
    'share': 29,
    'give': 29,
    'mean': 29,
    'politics': 29,
    'xi': 29,
    'experience': 29,
    'narrative': 29,
    'europeans': 29,
    'assurances': 29,
    'children': 28,
    'news': 28,
    'join': 28,
    'forward': 28,
    'quickly': 28,
    'impact': 28,
    'scenario': 28,
    'half': 28,
    'appears': 28,
    'risks': 28,
    'relationship': 28,
    '100': 28,
    'odesa': 28,
    'expected': 28,
    'hope': 28,
    'serious': 28,
    'became': 28,
    'party': 28,
    'controlled': 28,
    'sources': 28,
    'story': 28,
    'stop': 27,
    'low': 27,
    'ability': 27,
    'effectively': 27,
    'turned': 27,
    'goals': 27,
    'parts': 27,
    'process': 27,
    'planning': 27,
    'events': 27,
    'trade': 27,
    'numbers': 27,
    'advanced': 27,
    'ministry': 27,
    'rocket': 27,
    'increase': 27,
    'issue': 27,
    'meanwhile': 27,
    'particular': 27,
    'providing': 27,
    'supporting': 27,
    'enemy': 27,
    'total': 27,
    'concerns': 27,
    'directly': 27,
    'changes': 27,
    'allow': 27,
    'comes': 27,
    'blinken': 27,
    'hand': 27,
    'weight': 27,
    'ever': 27,
    'length': 27,
    'similar': 26,
    'forced': 26,
    'form': 26,
    'self': 26,
    'article': 26,
    'having': 26,
    'seems': 26,
    'group': 26,
    'greater': 26,
    'hit': 26,
    'largely': 26,
    'prepared': 26,
    'october': 26,
    'baltic': 26,
    'policies': 26,
    'resolution': 26,
    'trying': 26,
    'invade': 26,
    'white': 26,
    'university': 26,
    'false': 26,
    'saudi': 26,
    'analysts': 26,
    'society': 26,
    'analysis': 26,
    'max': 26,
    'crimes': 25,
    'arms': 25,
    'ports': 25,
    'size': 25,
    'considered': 25,
    'deterrence': 25,
    'capacity': 25,
    'prevent': 25,
    'saying': 25,
    'neutrality': 25,
    'success': 25,
    '17': 25,
    'positions': 25,
    'men': 25,
    'created': 25,
    'always': 25,
    'institute': 25,
    'modern': 25,
    'companies': 25,
    'added': 25,
    'burns': 25,
    'speaking': 25,
    'century': 25,
    'thinking': 25,
    'america': 25,
    'understand': 25,
    'decades': 24,
    'recently': 24,
    'moment': 24,
    'done': 24,
    'expansion': 24,
    'resources': 24,
    'either': 24,
    'rights': 24,
    'achieve': 24,
    '40': 24,
    'effective': 24,
    'approach': 24,
    'launch': 24,
    'seek': 24,
    'multiple': 24,
    'giving': 24,
    'times': 24,
    'tanks': 24,
    'additional': 24,
    'powers': 24,
    'find': 24,
    'leading': 24,
    'perhaps': 24,
    'imperialism': 24,
    'min': 24,
    'narratives': 24,
    'mph': 24,
    'approx': 24,
    'building': 23,
    'designed': 23,
    'majority': 23,
    'bring': 23,
    'press': 23,
    'act': 23,
    'immediate': 23,
    'increased': 23,
    'al': 23,
    'resistance': 23,
    'action': 23,
    'water': 23,
    'move': 23,
    'failure': 23,
    'path': 23,
    'soon': 23,
    'caused': 23,
    'stability': 23,
    'various': 23,
    'doing': 23,
    'research': 23,
    'came': 23,
    'settlement': 23,
    'reconnaissance': 23,
    'opposition': 23,
    'opinion': 23,
    'heavily': 23,
    'northern': 23,
    'advances': 23,
    'imperial': 23,
    'content': 23,
    'campaigns': 23,
    'entire': 22,
    'ago': 22,
    'challenge': 22,
    'fear': 22,
    'experts': 22,
    'higher': 22,
    'points': 22,
    'problem': 22,
    'offer': 22,
    'nature': 22,
    'ensure': 22,
    'consider': 22,
    'potential': 22,
    '21': 22,
    'seriously': 22,
    'started': 22,
    'millions': 22,
    'aircraft': 22,
    '11': 22,
    '15': 22,
    'polish': 22,
    '14': 22,
    'calls': 22,
    'investment': 22,
    'conditions': 22,
    'changed': 22,
    'third': 22,
    'outcome': 22,
    'damaged': 22,
    'showed': 22,
    'empire': 22,
    'independent': 22,
    'turning': 22,
    'cyber': 22,
    'really': 22,
    'thought': 22,
    'visit': 22,
    'ties': 22,
    'ceasefire': 22,
    'vital': 22,
    'commercial': 22,
    'solution': 22,
    'recalled': 22,
    'iranian': 22,
    'limited': 21,
    'fire': 21,
    'reasons': 21,
    'target': 21,
    'propaganda': 21,
    'lithuania': 21,
    'unity': 21,
    'unlikely': 21,
    'production': 21,
    'matter': 21,
    'speech': 21,
    'twitter': 21,
    'bank': 21,
    'joint': 21,
    'jazeera': 21,
    '18': 21,
    'mark': 21,
    'asked': 21,
    'turkey': 21,
    'tank': 21,
    'challenges': 21,
    'completely': 21,
    'views': 21,
    'maintain': 21,
    'reconstruction': 21,
    'failed': 21,
    'saw': 21,
    'perspective': 21,
    'expect': 21,
    'mobilization': 21,
    'prices': 21,
    'december': 21,
    'asia': 21,
    'idea': 21,
    'cause': 21,
    'expectations': 21,
    'market': 21,
    'deeply': 21,
    'opportunity': 21,
    'climate': 21,
    'anything': 21,
    'dangerous': 20,
    'whole': 20,
    'sent': 20,
    'measures': 20,
    'moreover': 20,
    'solidarity': 20,
    'clearly': 20,
    'expert': 20,
    'vehicles': 20,
    'operational': 20,
    'follow': 20,
    'context': 20,
    'conventional': 20,
    'beginning': 20,
    'reports': 20,
    'defensive': 20,
    'advance': 20,
    'tactical': 20,
    'accept': 20,
    'claims': 20,
    'deep': 20,
    'cut': 20,
    'create': 20,
    'population': 20,
    'respond': 20,
    'expressed': 20,
    'massive': 20,
    'milley': 20,
    'concern': 20,
    'certain': 20,
    'price': 20,
    'require': 20,
    'light': 20,
    'seeking': 20,
    'helped': 20,
    'currently': 20,
    'conflicts': 20,
    'prepare': 20,
    'initiative': 20,
    'spread': 20,
    'win': 20,
    'afghanistan': 20,
    'hold': 20,
    'struggle': 20,
    'try': 20,
    'freedom': 20
}

# %%
peak_words = {}
keywords = [
    "war", "military", "invasion", "ammunition", "shells", "missile", "production", "counteroffensive", 
    "biden", "sanctions", "presidential", "election", "frozen", "assets", "trump", "aid", "oil", "resources", 
    "bombs", "humanitarian", "negotiate", "sovereignty", "imperialism", "ceasefire", 
    "propaganda"
]

for word in word_freq_peak:
    if word in keywords:
        peak_words[word] = word_freq_peak[word]
for word in keywords:
    if word not in peak_words:
        peak_words[word] = 0

peak_words = {
    'war': 1021,
    'military': 417,
    'invasion': 271,
    'biden': 113,
    'sanctions': 109,
    'aid': 66,
    'missile': 49,
    'humanitarian': 45,
    'oil': 34,
    'ammunition': 30,
    'negotiate': 30,
    'sovereignty': 29,
    'resources': 24,
    'imperialism': 24,
    'ceasefire': 22,
    'propaganda': 21,
    'production': 21,
    'shells': 0,
    'counteroffensive': 0,
    'presidential election': 0,
    'frozen assets': 0,
    'trump': 0,
    'bombs': 0
}

# %%
# Create frequency count for russia ukraine conflict in the middle

start_date = datetime(2023, 1, 1).date()
end_date = datetime(2023, 12, 30).date()
start_date_str = start_date.strftime('%Y-%m-%d')
end_date_str = end_date.strftime('%Y-%m-%d')
entire_text = ""
articles = []
peak_news = gn.search('allintext:(invasion OR conflict OR war OR crisis + ukraine + russia)', from_ = start_date_str, to_ = end_date_str)
for entry in peak_news["entries"]:
    #articles.append(datetime.strptime(entry["published"], "%a, %d %b %Y %H:%M:%S GMT"))
    # print(entry["title"])
    articles.append(entry["link"])
# sorted_date_link_tuples = sorted(articles)
# print(sorted_date_link_tuples)

for article in articles:
    try:
        scraper = Article(article)
        scraper.download()
        scraper.parse()
        text = scraper.text
        entire_text += text

    except Exception as e:
        print(f"Error parsing article: {e}")

# print(entire_text)
cleaned_text = re.sub(r'[^\w\s]', ' ', entire_text.lower())
#analyse word frequency

exclude_words = non_noun_adjective_verb_words = [
    # key words
    "russia", "ukraine", "russian", "ukrainian", "kyiv", "moscow"
    # Articles
    "a", "an", "the",
    
    # Prepositions
    "about", "above", "across", "after", "against", "along", "amid", "among", "around", "as", 
    "at", "before", "behind", "below", "beneath", "beside", "between", "beyond", "but", "by", 
    "despite", "down", "during", "except", "for", "from", "in", "inside", "into", "like", "near", 
    "of", "off", "on", "onto", "out", "outside", "over", "past", "per", "through", "throughout", 
    "to", "toward", "under", "underneath", "until", "up", "upon", "with", "within", "without",
    
    # Conjunctions
    "and", "but", "or", "nor", "for", "so", "yet", 
    
    # Pronouns
    "I", "you", "he", "she", "it", "we", "they", "me", "him", "her", "us", "them", "my", "mine", 
    "your", "yours", "his", "her", "hers", "its", "our", "ours", "their", "theirs", "what", "who", 
    "which", "whom", "whose", "this", "that", "these", "those", "such", "many", "much", "few", 
    "little", "more", "most", "some", "any", "each", "every", "all", "another", "other", "same", 
    "one", "two", "three", "four", "five", "first", "second", "last", 
    
    # Interjections
    "wow", "ouch", "oops", "oh", "yeah", "yikes", "ugh", "uh-huh", "uh-oh", "hmm", "huh",
    
    # Others
    "etc", "et al", "e.g.", "i.e.", "etc.", "has", "have", "would", "should", "if", "is", "am", 
    "are", "be", "been", "being", "was", "were", "can", "could", "may", "might", "must", "shall", 
    "should", "will", "would", "shall", "should", "could", "might", "must", "would", "wont", "wont", 
    "cant", "couldnt", "didnt", "doesnt", "dont", "hadnt", "hasnt", "havent", "havnt", "isnt", "shouldnt", 
    "wasnt", "werent", "wont", "not", "now", "make", "things", "given", "also", "said", "states", "world", 
    "western", "there", "had"
]


word_counter_mid = Counter(word for word in cleaned_text.split() if word not in exclude_words and len(word) > 1)

print(word_counter_mid)

middle_words = {}
keywords = [
    "war", "military", "invasion", "ammunition", "shells", "missile", "production", "counteroffensive", 
    "biden", "sanctions", "presidential", "election", "frozen", "assets", "trump", "aid", "oil", "resources", 
    "bombs", "humanitarian", "negotiate", "sovereignty", "imperialism", "ceasefire", 
    "propaganda"
]

for word in word_counter_mid:
    if word in keywords:
        middle_words[word] = word_counter_mid[word]
for word in keywords:
    if word not in middle_words:
        middle_words[word] = 0

print(middle_words)

middle_freq = {
    'invasion': 216,
    'war': 859,
    'military': 333,
    'sanctions': 87,
    'negotiate': 11,
    'biden': 36,
    'aid': 96,
    'missile': 31,
    'ammunition': 23,
    'counteroffensive': 38,
    'presidential': 18,
    'election': 15,
    'propaganda': 13,
    'humanitarian': 41,
    'oil': 32,
    'trump': 11,
    'ceasefire': 13,
    'production': 22,
    'assets': 10,
    'resources': 27,
    'sovereignty': 14,
    'shells': 5,
    'bombs': 3,
    'frozen': 8,
    'imperialism': 7
}
# Out:
# Error parsing article: Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/world/europe/blood-billions-cost-russias-war-ukraine-2023-08-23/ on URL https://news.google.com/rss/articles/CBMiWGh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2V1cm9wZS9ibG9vZC1iaWxsaW9ucy1jb3N0LXJ1c3NpYXMtd2FyLXVrcmFpbmUtMjAyMy0wOC0yMy_SAQA?oc=5
# Error parsing article: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.state.gov/russias-strategic-failure-and-ukraines-secure-future/ on URL https://news.google.com/rss/articles/CBMiS2h0dHBzOi8vd3d3LnN0YXRlLmdvdi9ydXNzaWFzLXN0cmF0ZWdpYy1mYWlsdXJlLWFuZC11a3JhaW5lcy1zZWN1cmUtZnV0dXJlL9IBAA?oc=5
# Error parsing article: Article `download()` failed with 403 Client Error: Forbidden for url: https://carnegieeurope.eu/strategiceurope/89183 on URL https://news.google.com/rss/articles/CBMiL2h0dHBzOi8vY2FybmVnaWVldXJvcGUuZXUvc3RyYXRlZ2ljZXVyb3BlLzg5MTgz0gEA?oc=5
# ...

# %%
# Create frequency count for russia ukraine conflict now

start_date = datetime(2023, 12, 20).date()
end_date = datetime(2024, 4, 11).date()
start_date_str = start_date.strftime('%Y-%m-%d')
end_date_str = end_date.strftime('%Y-%m-%d')
entire_text = ""
articles = []
peak_news = gn.search('allintext:(invasion OR conflict OR war OR crisis + ukraine + russia)', from_ = start_date_str, to_ = end_date_str)
for entry in peak_news["entries"]:
    print(entry["title"])
    #articles.append(datetime.strptime(entry["published"], "%a, %d %b %Y %H:%M:%S GMT"))
    articles.append(entry["link"])
    
sorted_date_link_tuples = sorted(articles)

for article in articles:
    try:
        scraper = Article(article)
        scraper.download()
        scraper.parse()
        text = scraper.text
        entire_text += text

    except Exception as e:
        print(f"Error parsing article: {e}")

#print(entire_text)
cleaned_text = re.sub(r'[^\w\s]', ' ', entire_text.lower())
#analyse word frequency

exclude_words = non_noun_adjective_verb_words = [
    # key words
    "russia", "ukraine", "russian", "ukrainian", "kyiv", "moscow"
    # Articles
    "a", "an", "the",
    
    # Prepositions
    "about", "above", "across", "after", "against", "along", "amid", "among", "around", "as", 
    "at", "before", "behind", "below", "beneath", "beside", "between", "beyond", "but", "by", 
    "despite", "down", "during", "except", "for", "from", "in", "inside", "into", "like", "near", 
    "of", "off", "on", "onto", "out", "outside", "over", "past", "per", "through", "throughout", 
    "to", "toward", "under", "underneath", "until", "up", "upon", "with", "within", "without",
    
    # Conjunctions
    "and", "but", "or", "nor", "for", "so", "yet", 
    
    # Pronouns
    "I", "you", "he", "she", "it", "we", "they", "me", "him", "her", "us", "them", "my", "mine", 
    "your", "yours", "his", "her", "hers", "its", "our", "ours", "their", "theirs", "what", "who", 
    "which", "whom", "whose", "this", "that", "these", "those", "such", "many", "much", "few", 
    "little", "more", "most", "some", "any", "each", "every", "all", "another", "other", "same", 
    "one", "two", "three", "four", "five", "first", "second", "last", 
    
    # Interjections
    "wow", "ouch", "oops", "oh", "yeah", "yikes", "ugh", "uh-huh", "uh-oh", "hmm", "huh",
    
    # Others
    "etc", "et al", "e.g.", "i.e.", "etc.", "has", "have", "would", "should", "if", "is", "am", 
    "are", "be", "been", "being", "was", "were", "can", "could", "may", "might", "must", "shall", 
    "should", "will", "would", "shall", "should", "could", "might", "must", "would", "wont", "wont", 
    "cant", "couldnt", "didnt", "doesnt", "dont", "hadnt", "hasnt", "havent", "havnt", "isnt", "shouldnt", 
    "wasnt", "werent", "wont", "not", "now", "make", "things", "given", "also", "said", "states", "world", 
    "western", "there", "had", "re", "no", "than", "country", "moscow", "europe", "united", "even", "time", "long", "000", 
    "government", "west", "international", "when", "only", "since", "new", "because", "use", "do", "including", "months", 
    "years", "eastern", "made", "well", "just", "own"
]


# word_counter = Counter(word for word in cleaned_text.split() if word not in exclude_words and len(word) > 1)

# print(word_counter)
# Out:
# Two Years in, Russia's War on Ukraine Continues to Pose Threat to Global Security - Department of Defense
# Global Perspectives on Ending the Russia-Ukraine War - Council on Foreign Relations
# Ukraine War Takes a Toll on Russia - United States Institute of Peace
# Ukraine in maps: Tracking the war with Russia - BBC.com
# Russia-Ukraine war: List of key events, day 751 - Al Jazeera English
# Russia-Ukraine war: How Ukraine lost Avdiivka to Russia - The Associated Press
# Russia's War On Ukraine - Two Years On - Forbes
# Western weakness in Ukraine could provoke a far bigger war with Russia - Atlantic Council
# Russia-Ukraine war: List of key events, day 748 - Al Jazeera English
# The toll on Russia from its war in Ukraine, by the numbers - Atlantic Council
# Ukraine war: Three ways the conflict could go in 2024 - BBC.com
# Russia-Ukraine war: Putin waits for Western support to wither - The Associated Press
# Russia-Ukraine war: List of key events, day 777 - Al Jazeera English
# ...

# %%
word_freq_now = {
    'war': 440,
    'military': 165,
    'putin': 130,
    'forces': 82,
    'invasion': 79,
    'aid': 73,
    'support': 69,
    'troops': 68,
    'president': 61,
    'soldiers': 61,
    'ammunition': 58,
    'going': 58,
    'key': 58,
    'events': 58,
    'way': 55,
    'end': 54,
    '2024': 54,
    'drones': 54,
    'zelenskyy': 54,
    'conflict': 53,
    'weapons': 53,
    'developments': 52,
    'enters': 52,
    'front': 51,
    'scale': 50,
    'still': 50,
    'defense': 50,
    'european': 50,
    'list': 50,
    'say': 50,
    'media': 48,
    '2022': 48,
    'fighting': 48,
    'full': 47,
    'here': 46,
    'lines': 46,
    'air': 46,
    'then': 46,
    'told': 46,
    'likely': 45,
    'don': 45,
    'both': 44,
    'range': 44,
    'city': 43,
    'important': 43,
    'used': 41,
    'counteroffensive': 40,
    'political': 40,
    'want': 40,
    'ap': 39,
    'really': 39,
    'february': 38,
    'countries': 38,
    'able': 38,
    'men': 38,
    'economy': 37,
    'right': 37,
    'fight': 37,
    'peace': 36,
    'production': 36,
    'need': 36,
    'nato': 36,
    'army': 36,
    'global': 35,
    'missiles': 35,
    'security': 34,
    'state': 34,
    'artillery': 34,
    'information': 34,
    'see': 34,
    'attacks': 33,
    'get': 33,
    'social': 33,
    'least': 32,
    'continue': 32,
    'operations': 32,
    'public': 32,
    'million': 32,
    'power': 30,
    'according': 30,
    'fire': 30,
    'battlefield': 30,
    'look': 29,
    'election': 29,
    'sea': 29,
    'region': 29,
    'territory': 28,
    'equipment': 28,
    'black': 28,
    'arms': 27,
    'killed': 27,
    'news': 27,
    'force': 27,
    'victory': 27,
    'sanctions': 26,
    'economic': 26,
    'strategy': 26,
    'failed': 26,
    'offensive': 26,
    'vladimir': 25,
    'brigade': 25,
    'plant': 25,
    'china': 25,
    'money': 25,
    'assets': 25,
    'frozen': 24,
    'significant': 24,
    'taken': 24,
    'high': 24,
    'shells': 24,
    'put': 24,
    'crimea': 24,
    'foreign': 24,
    'hold': 23,
    'next': 23,
    'domestic': 23,
    'photo': 23,
    'allies': 23,
    'sense': 23,
    'does': 23,
    'national': 23,
    'jones': 23,
    'go': 22,
    'leaders': 22,
    'presidential': 22,
    'anti': 22,
    'terms': 22,
    'officials': 22,
    'ground': 22,
    'volodymyr': 22,
    'chief': 22,
    'biden': 22,
    'keep': 21,
    'defensive': 21,
    'already': 21,
    'increasingly': 21,
    'nearly': 21,
    'began': 21,
    'home': 21,
    'situation': 21,
    'council': 21,
    'congress': 21,
    'win': 21,
    'cost': 21,
    'billion': 21,
    'saturday': 21,
    'part': 21,
    'doing': 21,
    'tactics': 20,
    'march': 20,
    'number': 20,
    'enough': 20,
    'southern': 20,
    'eu': 20,
    '10': 20,
    'future': 20,
    'oil': 20,
    'clear': 20,
    'manpower': 20,
    'side': 20,
    'industry': 20,
    'needs': 20,
    'systems': 20,
    'course': 20,
    'europeans': 20,
    'mike': 20,
    'hemil': 20,
    'however': 19,
    'find': 19,
    'different': 19,
    'large': 19,
    'week': 19,
    'losses': 19,
    'lost': 19,
    'means': 19,
    'half': 19,
    'position': 19,
    'seen': 19,
    'third': 19,
    'short': 19,
    'missile': 19,
    'advantage': 19,
    'though': 19,
    'numbers': 18,
    'resources': 18,
    'summer': 18,
    'early': 18,
    'taking': 18,
    'whether': 18,
    'several': 18,
    'commander': 18,
    'group': 18,
    '2': 18,
    'price': 18,
    'remains': 18,
    'recently': 18,
    'push': 18,
    'effectively': 18,
    'tank': 18,
    'place': 17,
    'influence': 17,
    'opposition': 17,
    'total': 17,
    'life': 17,
    'north': 17,
    '3': 17,
    'intelligence': 17,
    'positions': 17,
    'donetsk': 17,
    'system': 17,
    'enemy': 17,
    'point': 17,
    'possible': 17,
    'union': 17,
    'done': 17,
    'vickers': 17,
    'south': 16,
    'set': 16,
    'fleet': 16,
    'vehicles': 16,
    'longer': 16,
    'armed': 16,
    'low': 16,
    'focus': 16,
    'asked': 16,
    'currently': 16,
    'feb': 16,
    'kind': 16,
    'problems': 16,
    'didn': 16,
    'call': 16,
    'drone': 16,
    'real': 16,
    'success': 16,
    'warfare': 16,
    'ability': 16,
    'december': 16,
    'research': 16,
    'particularly': 16,
    'talks': 16,
    'ministry': 16,
    'attack': 16,
    'june': 16,
    'big': 16,
    'example': 16,
    'age': 16,
    'defence': 16,
    'soviet': 15,
    'defeat': 15,
    'start': 15,
    'less': 15,
    'itself': 15,
    'training': 15,
    'effort': 15,
    'infrastructure': 15,
    'family': 15,
    'thousands': 15,
    'control': 15,
    'death': 15,
    'serious': 15,
    'left': 15,
    'east': 15,
    'pressure': 15,
    'biggest': 15,
    'report': 15,
    'continued': 15,
    'atlantic': 15,
    'attrition': 15,
    'taiwan': 15,
    'today': 15,
    'human': 15,
    'aggression': 15,
    'recent': 15,
    'minister': 15,
    'strategic': 15,
    'heavy': 15,
    'file': 15,
    'ongoing': 15,
    'occupied': 15,
    'armistice': 15,
    'population': 15,
    'true': 15,
    'american': 15,
    'getting': 15,
    'cohen': 15,
    'law': 14,
    'held': 14,
    '24': 14,
    'rate': 14,
    '25': 14,
    'using': 14,
    'hundreds': 14,
    'via': 14,
    'running': 14,
    'took': 14,
    'times': 14,
    'order': 14,
    'won': 14,
    'campaign': 14,
    'thinking': 14,
    'give': 14,
    'combat': 14,
    'independent': 14,
    'self': 14,
    'become': 14,
    'initiative': 14,
    'capabilities': 14,
    'll': 14,
    'service': 14,
    'house': 14,
    'level': 14,
    'great': 14,
    'strike': 14,
    'needed': 14,
    'continues': 14,
    'successful': 14,
    'assistance': 14,
    'ways': 14,
    'parts': 14,
    'emily': 14,
    'indian': 14,
    'anniversary': 13,
    'fatigue': 13,
    'believe': 13,
    'again': 13,
    'conflicts': 13,
    'de': 13,
    'hard': 13,
    'later': 13,
    'fear': 13,
    'personnel': 13,
    '20': 13,
    'deep': 13,
    'munitions': 13,
    '5': 13,
    'fact': 13,
    'entire': 13,
    'late': 13,
    'increase': 13,
    'navalny': 13,
    'almost': 13,
    'coke': 13,
    'fellow': 13,
    'days': 13,
    'major': 13,
    'got': 13,
    'idea': 13,
    'started': 13,
    'supply': 13,
    'coming': 13,
    'forced': 13,
    'eurasia': 13,
    'online': 13,
    'efforts': 13,
    'bakhmut': 13,
    'digital': 13,
    'propaganda': 13,
    'either': 13,
    'based': 13,
    'trying': 13,
    'video': 13,
    'trump': 13,
    'potential': 13,
    'financial': 13,
    'wagner': 13,
    'additional': 13,
    'cease': 13,
    'border': 13,
    'areas': 13,
    'disinformation': 13,
    'israel': 13,
    'eliot': 13,
    'harding': 13,
    'hon': 13,
    'remain': 12,
    'area': 12,
    'standing': 12,
    'battle': 12,
    'having': 12,
    'infantry': 12,
    'korea': 12,
    'provide': 12,
    'analysts': 12,
    'spending': 12,
    'central': 12,
    'role': 12,
    'lack': 12,
    'pro': 12,
    'leader': 12,
    'making': 12,
    'bombs': 12,
    'called': 12,
    'provided': 12,
    'something': 12,
    'sides': 12,
    'ready': 12,
    'understand': 12,
    'cities': 12,
    'change': 12,
    'certainly': 12,
    'work': 12,
    'ago': 12,
    'policy': 12,
    'interests': 12,
    'case': 12,
    'difficult': 12,
    'multiple': 12,
    'run': 12,
    'wanted': 12,
    'moment': 12,
    'current': 12,
    'scenario': 12,
    'shortages': 12,
    'pull': 12,
    'stop': 11,
    'happens': 11,
    'experts': 11,
    'partners': 11,
    'response': 11,
    'sign': 11,
    'captured': 11,
    'earlier': 11,
    'kharkiv': 11,
    'break': 11,
    'led': 11,
    'energy': 11,
    'supplies': 11,
    'open': 11,
    'try': 11,
    'happen': 11,
    'draft': 11,
    'directly': 11,
    'man': 11,
    'm': 11,
    'commanders': 11,
    'capacity': 11,
    'analysis': 11,
    'defenses': 11,
    'views': 11,
    'units': 11,
    'challenges': 11,
    'tensions': 11,
    'saying': 11,
    'prigozhin': 11,
    'away': 11,
    'good': 11,
    'questions': 11,
    '18': 11,
    'conference': 11,
    'tanks': 11,
    'looking': 11,
    'd': 11,
    'play': 11,
    'towards': 11,
    'republicans': 11,
    'let': 11,
    'bit': 11
}

# %%
now_words = {}
keywords = [
    "war", "military", "invasion", "ammunition", "shells", "missile", "production", "counteroffensive", 
    "biden", "sanctions", "presidential", "election", "frozen", "assets", "trump", "aid", "oil", "resources", 
    "bombs", "humanitarian", "negotiate", "sovereignty", "imperialism", "ceasefire", 
    "propaganda"
]

for word in word_freq_now:
    if word in keywords:
        now_words[word] = word_freq_now[word]
        
for word in keywords:
    if word not in now_words:
        now_words[word] = 0
print(now_words)
now_words = {
    'war': 440,
    'military': 165,
    'invasion': 79,
    'aid': 73,
    'ammunition': 58,
    'counteroffensive': 40,
    'production': 36,
    'sanctions': 26,
    'presidential election': 25,
    'frozen assets': 24,
    'shells': 24,
    'biden': 22,
    'oil': 20,
    'missile': 19,
    'resources': 18,
    'propaganda': 13,
    'trump': 13,
    'bombs': 12,
    'humanitarian': 0,
    'negotiate': 0,
    'sovereignty': 0,
    'imperialism': 0,
    'ceasefire': 0
}
# Out:
# {'war': 440, 'military': 165, 'invasion': 79, 'aid': 73, 'ammunition': 58, 'counteroffensive': 40, 'production': 36, 'election': 29, 'sanctions': 26, 'assets': 25, 'frozen': 24, 'shells': 24, 'presidential': 22, 'biden': 22, 'oil': 20, 'missile': 19, 'resources': 18, 'propaganda': 13, 'trump': 13, 'bombs': 12, 'humanitarian': 0, 'negotiate': 0, 'sovereignty': 0, 'imperialism': 0, 'ceasefire': 0}

# %%
peak_percentages = {
    
    'biden': 0.11067580803134182, 'sanctions': 0.10675808031341821, 
    'missile': 0.047992164544564155, 'humanitarian aid': 0.04407443682664055, 'oil': 0.01530068560235064,
    'ammunition': 0.029382957884427033, 'negotiate': 0.029382957884427033, 
    'resources': 0.018506366307541625, 'ceasefire': 0.021547502448579822,
    'propaganda': 0.02056807051909892, 'production': 0.02056807051909892, 'shells': 0.0, 'counteroffensive': 0.0,
    'presidential election': 0.0, 'frozen assets': 0.0, 'trump': 0.0, 'bombs': 0.0
}

middle_percentage = {
    
    'sanctions': 0.10128055878928988, 'humanitarian aid': 0.047729918509895226,
    'counteroffensive': 0.04423748544819558, 'biden': 0.04190919674039581, 'oil': 0.023252619324796274,
    'missile': 0.03608847497089639, 'resources': 0.024143189755529686, 'ammunition': 0.02677532013969732,
    'production': 0.025611175785797437, 'presidential election': 0.017462165308498253, 
    'propaganda': 0.015133876600698487, 'ceasefire': 0.015133876600698487, 'frozen assets': 0.009313154831199068,
    'shells': 0.005820721769499418, 'negotiate': 0.012805587892898719,
    'trump': 0.012805587892898719, 'bombs': 0.0034924330616996507
}

now_percentages = {
    'ammunition': 0.1318181818181818, 'counteroffensive': 0.09090909090909091, 'production': 0.08181818181818182,
    'sanctions': 0.05909090909090909, 'presidential election': 0.056818181818181816, 'frozen assets': 0.05454545454545454,
    'shells': 0.05454545454545454, 'biden': 0.05, 'oil': 0.045454545454545456, 'missile': 0.04318181818181818,
    'resources': 0.04090909090909091, 'propaganda': 0.029545454545454545, 'trump': 0.029545454545454545,
    'bombs': 0.02727272727272727, 'humanitarian aid': 0.0, 'negotiate': 0.0,
    'ceasefire': 0.0
}

""""'military': 0.40842311459353575, 'invasion': 0.2654260528893242,"""
""""'military': 0.38766006984866125, 'invasion': 0.25145518044237486,"""
"""'military': 0.375, 'invasion': 0.17954545454545454,""" 

# 'aid': 0.11175785797438882,'aid': 0.16590909090909092,'aid': 0.06464250734573947,
# Out:
# "'military': 0.375, 'invasion': 0.17954545454545454,"

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

colors = ['#D0CECE','#2D8FD4','#3742AE', '#300aab', '#3A3A3A']
positions = [0, 0.25, 0.5, 0.75, 1]

# Create a colormap with the custom colors
custom_cmap = LinearSegmentedColormap.from_list("custom_cmap", list(zip(positions, colors)))

peak_df = pd.DataFrame(peak_percentages.items(), columns=['Word', 'Percentage'])
peak_df['Year'] = '2022'
middle_df = pd.DataFrame(list(middle_percentage.items()), columns=['Word', 'Percentage'])
middle_df['Year'] = '2023'
now_df = pd.DataFrame(list(now_percentages.items()), columns=['Word', 'Percentage'])
now_df['Year'] = '2024'

# Concatenate all DataFrames
all_data = pd.concat([peak_df, middle_df, now_df])
# Pivot the data to create a heatmap
heatmap_data = all_data.pivot(index='Word', columns='Year', values='Percentage')
ax = sns.heatmap(heatmap_data, cmap = custom_cmap, cbar_kws={'ticks': []})
ax.figure.axes[0].set_xlabel('')
ax.figure.axes[0].set_ylabel('')
plt.show()

# %%
from matplotlib.colors import LinearSegmentedColormap
colors = ['#A0A1BA','#05B7E1','#1750CF','#3527BF', '#3A3A3A']
positions = [0, 0.25, 0.5, 0.75, 1]

# Create a colormap with the custom colors
custom_cmap = LinearSegmentedColormap.from_list("custom_cmap", list(zip(positions, colors)))
heatmap_data = all_data.pivot(index='Word', columns='Year', values='Percentage')
ax = sns.heatmap(heatmap_data, cmap = custom_cmap, linewidths=0.5, cbar_kws={'ticks': [], 'label': 'Frequency'})
ax.figure.axes[0].set_xlabel('')
ax.figure.axes[0].set_ylabel('')
plt.show()
